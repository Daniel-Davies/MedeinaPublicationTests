# %%
import os 
import matplotlib.pyplot as plt
import networkx as nx
import pickle
import itertools
import seaborn as sns
import pandas as pd
resultExact = "C:/Users/davie/Desktop/results/leaveout"
resultGenus = "C:/Users/davie/Desktop/results/leaveoutgenus"
resultFamily = "C:/Users/davie/Desktop/results/leaveoutfamily"
files = os.listdir(resultExact)
from pylab import rcParams
rcParams['figure.figsize'] = 20, 15
files[0]
# Out:
# 'BaseCSV#plantPollinatorUSA'

# %%
def getResultsForCategory(basepath):
    doneNotDone = []
    ecoTransTime = []
    buildTime = []
    results = []
    actuals = []
    for item in files:
        with open(basepath+"/"+item,'rb') as f:
            arr = pickle.load(f)
            result,actual,allInteractions,finalTime,translatedTime,done,notDone = arr[0]
            doneNotDone.append([done,notDone])
            namesLen = len(set(itertools.chain(*actual)))
            ecoTransTime.append([namesLen,translatedTime])
            results.append(result)
            actuals.append(actual)
            buildTime.append([namesLen,finalTime-translatedTime])
    return buildTime,doneNotDone,ecoTransTime,results,actuals

# %%
len((1,3,4))
# Out:
# 3

# %%
ecoTransTimeExact = getResultsForCategory(resultExact)[2]
ecoTransTimeGenus = [] #getResultsForCategory(resultGenus)[2]
ecoTransTimeFamily = [] #getResultsForCategory(resultFamily)[2]
ecoTransTime = list(map(lambda x: sum(x) / len(x),zip(ecoTransTimeExact,ecoTransTimeGenus,ecoTransTimeFamily)))
dataSet = pd.DataFrame(ecoTransTime,columns=['Number of Names','Translation Time'])
ax = sns.scatterplot(x="Number of Names", y="Translation Time",data=dataSet)
labels = [w.get_text() for w in ax.get_xticklabels()]
locs=list(ax.get_xticks())
labels=['0','50','200','400','600','800','1000']
locs=[0,50,200,400,600,800,1000]
ax.set_xticklabels(labels)
ax.set_xticks(locs)
plt.xlabel("Number of Names",fontsize=15)
plt.ylabel("Translation Time (s)",fontsize=15)
plt.axvline(x=50,c='r')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-690c9b8478e8> in <module>
#       2 # ecoTransTimeGenus = getResultsForCategory(resultGenus)[2]
#       3 # ecoTransTimeFamily = getResultsForCategory(resultFamily)[2]
# ----> 4 ecoTransTime = list(map(lambda x: sum(x) / len(x),zip(ecoTransTimeExact,ecoTransTimeGenus,ecoTransTimeFamily)))
#       5 dataSet = pd.DataFrame(ecoTransTime,columns=['Number of Names','Translation Time'])
#       6 ax = sns.scatterplot(x="Number of Names", y="Translation Time",data=dataSet)
#
# NameError: name 'ecoTransTimeGenus' is not defined

# %%
def numCorrectlyIndexed(doneAndNotDoneTuples):
    x = list(map(lambda x: x[0]/sum(x) if sum(x) > 0 else 0,doneAndNotDoneTuples))
    g = sns.distplot(x, hist=True,kde=False,bins=20)
    plt.ylabel('Frequency', fontsize = 15) # x-axis label with fontsize 15
    plt.xlabel('% of species matched', fontsize = 15) # y-axis label with fontsize 15
    for p in g.patches:
        x=p.get_bbox().get_points()[:,0]
        y=p.get_bbox().get_points()[1,1]
        g.annotate(str(int(y)), (x.mean(), y), ha='center', va='bottom') # set the alignment of the text

results = getResultsForCategory(resultExact)
numCorrectlyIndexed(results[1])

# %%
import itertools
results = getResultsForCategory(resultExact)[1]
results = set(itertools.chain(*map(lambda x: x[1],results)))
results
# Out:
# {'',
#  'reduviids',
#  'young fish',
#  'Oligochaete Type II',
#  'Killer Whales C',
#  "Lumbriculiid oligochaete unknown 'long' (CG)",
#  'P. ternetzi',
#  'belvedere summer cypress (forb/shrub)',
#  'Chionobis macouni',
#  'Unreared hispine sp.6',
#  'submerged macrophytes (Blyxa - Cryptocoryne - Nitella)',
#  'mangrove leaves',
#  'hymenolepidid cestodes',
#  'CYCLOPOID COPEPODS (Mesocyclops sp.)',
#  'filter feeders',
#  'trout, jack',
#  'terrestrial flies',
#  'Encyrtid (near Tachinaephagus)',
#  'C: cephalopod aggregate',
#  '13-striped spermophile (ground squirrel)',
#  'Carnivorous zooplankton',
#  'Stigeid',
#  'Tendipedidae (unspecified)',
#  'cecidomyid larvae (undet.)',
#  'Terrestrial bugs',
#  'Nauplii sp.',
#  'Nematode',
#  'predaceous crabs',
#  'Asteroidea',
#  'carnivorous arthropods',
#  'Cyanobacteria',
#  'pike - large perch',
#  'Flatfish spp.',
#  'elasmobranch fishes',
#  'Hirud - Tricladida - Hydrachn',
#  'fine particulate organic matter',
#  'Hudsonema amabilis (n=10)',
#  'canker - fomes',
#  'nearshore phytoplankton',
#  'Dytiscid beetles',
#  'Scirtid sp. larvae (Broad type)',
#  "Lumbriculiid type 'skinny' (N=10)",
#  'RBgull',
#  'Cumaceans',
#  'insects in herb and surface stratum, Diptera, Hemiptera, grasshoppers, etc.',
#  'H. segmentaria larvae',
#  'SEDIMENT',
#  'insects in herb and surface stratum - Diptera - Hemiptera - grasshoppers - etc.',
#  'Macquartia brevicornis (Panzer)',
#  'Meligramma guttatum',
#  'ring-necked pheasent',
#  'Aves',
#  'Radiolarians',
#  'Dead cellular plant material',
#  'Gerreids',
#  'Unreared hispine sp.4',
#  'Single-cell algae',
#  'Myiatropa florea',
#  'phytoplankton cells below 10 micrometer',
#  'Elmid larvae',
#  'Unreared Lepidoptera sp.1',
#  'mesopelagic',
#  'Large single-cell algae or colonies',
#  'Phaneropria sp.',
#  'bottom organic matter - benthic macroalgae',
#  'Enopla 1',
#  'Large rotifers (carnivore)',
#  'leopard seals',
#  'Hermit crabs',
#  'Unknown organic',
#  'benthic crustacea',
#  'insectivorous birds & bats (unspec.)',
#  'wind-blown organic debris - pollen',
#  'gerbils, hares',
#  'Chrysobothris sp. larvae',
#  'Pseudo-Nitzschia subcurvata',
#  'asteroids',
#  'dipterous larvae',
#  'Brachyptera fasciata',
#  'Killifishes',
#  'Nauplii',
#  'Echinoids',
#  'three-cleft greenthread (forb/shrub)',
#  'Reinhardtius hipoglossoides',
#  'Adult sculpin',
#  'sediment bacteria',
#  'detritus',
#  'Smooth hawkbit',
#  'Empidae spD',
#  'browsers and grazers (gastropods, crustacea, etc.)',
#  'Dead organic material',
#  'terns',
#  'Other omnivores',
#  'Sarrothripinae sp',
#  'Fragmented leaf',
#  'Aufwuchs on Vallisneria',
#  'insects in soil stratum - wire worms - cutworms - white grubs - etc.',
#  'Antherix',
#  'fragmented leaf, stem tissue, moss',
#  'C. dorsalis',
#  'Hudsonema amabilis',
#  'Terrestrial Invertebrates',
#  'stream and airborne insects',
#  'meiofauna',
#  'bottom organic matter',
#  'anthomyiid fly',
#  'predatory cephalopods',
#  "doves, Palmer's thrasher, sage sparrow, Lark bunting, House finch, goldfinch, Gambel sparrow",
#  'filter-feeding - minnow-like fishes',
#  'pelecypod 2',
#  'PiscF7: sablefish',
#  'Otocryptops sexspinosus',
#  'other groundfish',
#  'terrestrial inverteb. (hymenopteran)',
#  'UNIDENTIFIED FISH (FRAGMENT)',
#  'Discard',
#  'Charips sp.',
#  'Unidentified sp1 M_PL_035',
#  'Cirripedia',
#  'large particle detritus',
#  'Scirtid sp. (Broad type)',
#  'Maryland yellow-throat',
#  'Calcidoidae sp 1',
#  'Benthos',
#  'primary carnivores',
#  'Trichoptera larvae',
#  'protozoa (fresh water plankton)',
#  'frustv',
#  "Chironomid type 'Orthoclad blue blond'",
#  'bivalves, nematodes, cumaceans, polychaetes, small crustacea, fish',
#  'PiscMM2: large pinnipeds',
#  'Hydrophiliid beetle (N=3)',
#  'young smelt',
#  'Leaves',
#  'haplotaxid worms',
#  'wood rats',
#  'Rotatoria',
#  'demersal species',
#  'Craspedochoeta pullula',
#  'animal dung',
#  'carcass',
#  'phloem (Quercus spp.)',
#  'large sized Euphausiacea, Mysidacea, Hyperiidea, Ostracoda',
#  'Unknown Forb B',
#  'crickets',
#  'nauplii - small sized Euphausiacea - Mysidacea - Hyperiidea - Ostracoda',
#  'S. sp. second instar',
#  'S. robustum',
#  'PlnkF2bii: Chinook yearling',
#  'Pied Billed Grebe',
#  'P. turbida adults',
#  '0',
#  'anemones, tunicates',
#  'vascular plants',
#  'toad carrion',
#  'A. albopunctatus',
#  'Stony corals',
#  'young leaves',
#  'Unreared agromyzid sp.23',
#  'aves (unspecified)',
#  'higher plants',
#  'Elateroidea sp2',
#  'Double Crested Cormorant',
#  'tipulids (unspec.)',
#  'nematode n',
#  'Bosminia',
#  'predaceous Collembola',
#  'redpolls',
#  'bombus dorsalis',
#  'anemones',
#  'macroalgae, eelgrass',
#  'Krill larvae',
#  'Parasitoids (Synodites lineiger - Ichneutes hyperboreus)',
#  'fulmars',
#  'Bombomelecta fulvida',
#  'submerged root plants',
#  'shrews',
#  'Microcoelepis sp.',
#  'T. paraguayensis',
#  'Other phytoplankton',
#  'Spiny Lobsters',
#  'Copepods - Meroplankton',
#  'ducks',
#  'D. distinctus (0.4-0.6 mm HCW)',
#  'Chitin fragments',
#  'sub-surface deposit-feeding polychaetes',
#  "Chrinomid type 'Eukief Shiny Black' (n=4)",
#  'man',
#  'Black bryony',
#  "Chironomid type 'Tanytarsini' (n=10)",
#  'Flounder and needlefish',
#  'Unknown Forb D',
#  'Acarid sp.',
#  'Parasidea raggiana',
#  'Carposcalis obscura',
#  'Agrostis atritegulator Hampson',
#  'algal mats, crusts',
#  'Asilis pilicomis',
#  'Parasitoid (Atractodes pusillus)',
#  'CYCLOPOID COPEPODITE',
#  'Gastrotrich unknown',
#  'Cyanophyta',
#  'Fish eating birds',
#  'Oligo four chaetae',
#  'Hudsonema amabilis ',
#  'piscivorous fish',
#  'Crymodes exulis',
#  'carnivorous invertebrates',
#  'P. curviventris',
#  'Chalcidoma disjunctum',
#  'Unidentified sp2 M_PL_035',
#  'Microspora sp.',
#  'secondary carnivores',
#  'juvenile euphausiids',
#  'lepidopterous larvae',
#  'Unknown green algae filaments',
#  'Amphi-trematode sp.',
#  'Sterna paradisea',
#  'dead birds etc. washed in from sea',
#  'Microspora',
#  'Unreared agromyzid sp.13',
#  'C. lucaris',
#  "Lumbriculiid 'slim white' (CG)",
#  'geckos',
#  'misc. fur - feather - fin',
#  'Scaly-breasted Thrasher',
#  'pulverized masses',
#  'C. semifascia',
#  'Anchoa mitchelli',
#  'bumblebees - butterflies - aphids - weevils',
#  'soybean plant',
#  'frogs, lizards, birds',
#  'O. septentrionalis',
#  'Eukiefiriella (N=2)',
#  'Herbivorous Crustaceans',
#  'lichens - mosses',
#  'Hemichordates',
#  'grass Schismus barbatus',
#  'L. weddellii/O. rossii',
#  'PROTOZOA: Cyphoderia sp.',
#  'Pseudo-Nitzschia prolongatoides',
#  'C. microtretus',
#  'Chilopoda',
#  'grasses - sedges - willows',
#  'mollusks',
#  'Stictocaldius',
#  'Chloropid (unspecified)',
#  'Detritivorous fish',
#  'PlnkF1d: herring',
#  'Adult planktivorous fish',
#  'C. kirbii',
#  'fish - birds - mammals',
#  'saprovores',
#  'Adult hake',
#  'tundra vegetation',
#  'benthic bacteria',
#  'Canosoma crassus',
#  'seals',
#  'Road runner',
#  'Suwalia (P)',
#  'Unknown Forb R',
#  'Scirtid sp. (larva) (n=3) ',
#  'solitary tunicates',
#  "Chironomid type 'Orthoclad Blue Blond' (n=4)",
#  'Potamo - Bithyn - Lymn',
#  'Eukiefidrella',
#  'Ectoprocta',
#  'submergent vascular plants',
#  'Jackass morwong',
#  'Unknown Forb G',
#  'Dialictus obscurus',
#  'Patellogastropoda',
#  'frigate birds',
#  'T. tenuicaudus',
#  'animal carcasses',
#  'flies - Dermestes - Calliphora - Phaleria (carrion beetles and flies)',
#  'Deposit-feeding polychaetes',
#  'Medusae, Ctenophora',
#  'Dreissenid mussels',
#  'Yramea modesta',
#  'marsh hawk',
#  'lumbricid (undet.)',
#  'Mackerels',
#  'Hudsonema amabilis (N=1)',
#  'pike - adult yellow perch (Perca)',
#  'Agrostis atritegulator',
#  'A. pantaneiro',
#  'Epiphyte-grazing amphipods',
#  'hawks and owls (7 species)',
#  'Hudsonimya sp.(N=1)',
#  'Detritus Animal',
#  'Grey Duck',
#  'mites - centipedes',
#  "Lumbriculiid Type 'II'  (N=10)",
#  'Unreared Lepidoptera sp.22',
#  'Sepsid_sp.',
#  'Heterotrophic nanoflagellates',
#  'Allochthonous Diptera',
#  'Hudsonema aliena (McLachlan)',
#  'iron bacteria',
#  'Filament Algae',
#  'Terrestrial plants',
#  'Larvaceans',
#  "Chironomid type 'Diamesid blond'",
#  'tumbleweed amaranth (forb/shrub)',
#  'halictid',
#  'macrocrustacea',
#  'Medusozoa',
#  'Maryland yellowthroat, yellow warbler, songsparrow',
#  'M. domestica larvae',
#  'plankton',
#  'Orthocladiariae sp.',
#  'Necterosoma penicillatus - adult (Chironomidae - Dytiscidae)',
#  'Aphrotenidae',
#  'Staurostratum',
#  'lichens, mosses',
#  'Euspilotus aenicollis',
#  'porcupines',
#  'gammarids',
#  'Other salmonines',
#  'R. planifrons',
#  'Syrphid',
#  'prairie spiderwart (forb/shrub)',
#  'Hudsonema aliena (N=1)',
#  'Dolphins',
#  'Unreared Lepidoptera sp.27',
#  'Chrysomonads',
#  'Unidentified bee sp1',
#  "Chironomid type 'Diamesid Blond'",
#  'water column labile detritus',
#  'snakes - gharial - turtles',
#  'Tardigrade unknown',
#  'nauplii, small sized Euphausiacea, Mysidacea, Hyperiidea, Ostracoda',
#  'encrusting and mat-forming algae',
#  'Invertebrate predators',
#  'terrestrial detritus',
#  'recently drowned insects',
#  'Large phytoplankton',
#  'Aleocharine B65',
#  'benthic invertebrates',
#  'Horse mackerels',
#  'four-o-clock (forb/shrub)',
#  'D3: benthic detritus',
#  'phytoplankton - suspended detritus',
#  'CYCLOPOID COPEPOD (Eucyclops sp.)',
#  'Sediment',
#  'Herrings',
#  'larvae of molluscs and polychaetes',
#  'trypanorynch',
#  'Acarina',
#  'other herbivores',
#  'DIATOMS (Eunotia sp.)',
#  'nereids',
#  'Pelecophora intemipta',
#  'Whales',
#  'Leptocera luteilabris',
#  'Unreared agromyzid sp.21',
#  'Limicolae, Anseres, Microtus (2 sp.), Arvicola',
#  'C. nigropunctata',
#  'Mites (Creutzeria sp)',
#  'Terrestrial invertebrate remains',
#  'Nephthys',
#  'Plactynemis',
#  'Herbivorous shrimps',
#  'Hesperocorixa linnei (Fieber)',
#  'Unknown Forb I',
#  'prawns and shrimps',
#  'large sized Euphausiacea - Mysidacea - Hyperiidea - Ostracoda',
#  'waterfowl, lemmings, squirrels',
#  'Dolichovespula diabolica',
#  'H. flavifacies eggs',
#  'Cnidarians (Hydromedusae - Scyphomedusae)',
#  'allochthonous detritus',
#  'Hyperids',
#  "Chironomid type 'Corynoneura' (n=1)",
#  'UNIDENTIFIED INSECT (FRAGMENT)',
#  'Ceratopogonid (N=1)',
#  'P. turbida larvae',
#  'Trumpet Manucode',
#  'coccids',
#  'E. ligata',
#  'Hudsonema amibilis',
#  'other large fish',
#  'dolphin Coryphaena',
#  'littorines',
#  'chestnut-collard longspur',
#  'Zwichia (2 spp.)',
#  'PiscMM1: small pinnipeds',
#  'Benthic algae',
#  'Polypedellum (N=4)',
#  'Orychmontia sp.',
#  'Phyoplankton',
#  'canopy animals -- birds - fruit bats and other mammals',
#  'Polypedellum  ',
#  'Anthrax halycon',
#  'jackal, hyena',
#  'Nematode ',
#  'syrphid larvae',
#  'Halictus lerouxi',
#  'ground--roots, fallen fruit, leaves and trunks',
#  'Eupelmid gen. n.',
#  'Costachorema xanthoptera',
#  'Osmia rohweri',
#  'Elateroidea sp3',
#  'Bluegreen algae',
#  'meroplankton - fish larvae',
#  'penguins - petrels',
#  'M. fuscipes',
#  'large benthic carnivores',
#  'BnthF4: Gadidae (cod, haddock, pollock)',
#  "Lumbriculiid type 'III' (N=1)",
#  'other fish',
#  'weasels (2 species)',
#  'clams',
#  'cutworms - grasshoppers - clickbeetles',
#  'algal mats - crusts',
#  'Troch',
#  'Adult helmids',
#  'voles - mice',
#  "Lumbriculiid type 'II' (N=10) ",
#  'UNIDENTIFIED INSECT (WHOLE)',
#  'flowering plants',
#  'phytoplankton and benthic algae',
#  'Lyniphia triangularis Clerck',
#  'Galaxias brevipennis (N=1)',
#  'bottom algae & detritus',
#  'PiscF4: piscivorous rockfish',
#  'Onisimus littoralis',
#  'carnivorous Calanoida',
#  'Oligo Lumbr. Blue (CG)',
#  'zoobenthos',
#  'Hydrozoans',
#  'Unidentified voucher No.28',
#  'Pseudo-Nitzschia liniola',
#  'Suspended detritus',
#  'Unknown blue green algal spp.',
#  'Unknown orthoclad',
#  'Muscid sp.',
#  'Rhodophyta',
#  'Adoxia',
#  'redwinged blackbird, bronze grackle, song sparrow',
#  'Vertebrate predators (fish)',
#  'C. divisa',
#  'Chalcidoidea',
#  'Copepods (Neocalanus cristatus - N. plumchrus)',
#  'Testate amoeba',
#  'Hudsonema amabilis (McLachlan)',
#  'Paranyctiophylax sp. (N=5)',
#  'vertebrate herbivores',
#  'phytoplankton (small particles)',
#  'ground -- roots - fallen fruit - leaves and trunks',
#  'M. amaenus',
#  'Hydrophilid unknown sp.',
#  'C. macellaria larvae',
#  'Z1c: invertebrate eggs',
#  'Dolochopodid adult (long-legged fly)',
#  'enopla 1',
#  "Chironomid type 'Brundin' (n=10)",
#  'dolicopodid larvae (undet.)',
#  'Acanthomyops niger',
#  'adult hymenopterans',
#  'E. longicollis',
#  'salticid spider',
#  'Unidentified organic material',
#  'redwinged blackbird - bronze grackle - song sparrow',
#  'Scritid brd',
#  'waterfowl, marsh rabbits, deer, water rat',
#  'land vegetation',
#  'protozoa (land)',
#  'Hyponigrus obsidianus',
#  'P. pullus',
#  'gulls',
#  'Unreared Lepidoptera sp.34',
#  'Unreared Lepidoptera sp.32',
#  'Eukiefidrella brundini (N=6)',
#  'predaceous Testate Amoebe',
#  'herons and kingfishers',
#  'benthonic vertebrates',
#  'small detritus particles',
#  'T. argenteus',
#  'Juvenile sculpin',
#  'Thysanura - Isoptera - other Tenebrionidae',
#  'jackal Canis aureaus',
#  'canker, fomes',
#  'marsh spiders',
#  'FISH SCALES',
#  'zooplankton',
#  'Indigenous catfishes',
#  'Tabanid sp.',
#  'Eupelmid n. genus',
#  'unknown ciliate',
#  'dipteran larvae and pupae (and other aquatic insects)',
#  'Oligo II (N=5)',
#  'grasshopper mice',
#  'floral parts',
#  'alpine vegetation',
#  "Lumbriculiid type 'Smooth'",
#  'detritus - organic matter',
#  'Number 40',
#  'pochard - swan - coot',
#  'top carnivores-tarpon, barracuda, bull shark, other fish, American alligator, bald eagle,',
#  'E. sternalis eggs',
#  'S. teretirostris',
#  'Spiders (Erigone arctica - Erigone psychrophila - Meioneta nigripes - Halorates spetsbergensis - Hilaira glacialis)',
#  'Evylaeus quebecensis',
#  'crabs - shrimps - gold-spotted killifish - crested goby',
#  'Loggerhead turtles',
#  'Pilinasica cingulata',
#  'baetids (unspec.)',
#  'Cephalopodes',
#  'Oligo. Lumbr. Pink (CG)',
#  'plankton and marine detritus',
#  'Hudsonema aliena',
#  'nannophytoplankton',
#  'Xyalophora quinquelineata',
#  'P. thyroideus',
#  'Mollusk',
#  'basic food',
#  'decapods',
#  'periphyton and benthic detritus',
#  'Unidentified detritus',
#  'mammals',
#  'fish herbivores',
#  'pollen (undet.)',
#  'dicots',
#  'Hyponigrus sp.',
#  'ooze - bacteria',
#  'Simulidae, Cricotopus, triannulatus, Orthocladius',
#  'pelagic fish (e.g., herring-like fish)',
#  'whales - crabeater seals',
#  'Demersal piscivores',
#  'Cryptophytes',
#  'Brachyptera fasciata (0.6-0.8 mm HCW)',
#  "Lumbriculiid Type 'I'",
#  'Acanthocephalan in Gillichthys',
#  'Polypedellum  (N=6)',
#  'Eliphilus latifrons',
#  'Memecylon eleagni',
#  'P. ruficolle',
#  'mites, landflies, adult chironomids, springtails',
#  'Suspension-feeding invertebrates',
#  "Chironomid type 'Diamesid brown orange'",
#  'surova',
#  'P. wisconsinense',
#  'Cyclopoid copepods',
#  'R. valuma',
#  'BnthF1: skates & rays',
#  'E. antarctica (90-120mm)',
#  'antelopes, gazelle, backbuck, nilgai',
#  'scarlet mite',
#  "Chironomid type 'Orthoclad Blue Black'",
#  'Killer Whales A',
#  'H. cadaverinus',
#  'Gastropods',
#  'T. discoloripes',
#  'geelbek',
#  'Large cladocerans',
#  'Euchanis',
#  'isopods, Gammarus, Caprella',
#  'Other Algae',
#  'Drapites sp. larvae',
#  'CALANOID COPEPOD (unidentified)',
#  'dead carcasses',
#  'Oligo II (N=3)',
#  'gall tissue (Atriplex polycarpa)',
#  'butterflies - moths',
#  'Allogyptus crenshawi',
#  'UNIDENTIFIED ANIMAL FRAGMENTS',
#  'phrea',
#  'Other insectivores',
#  'fry',
#  'M. autumnalis first instar',
#  'Aquatic macrophytes',
#  'Unidentified sp7 M_PL_010',
#  'Maryland yellowthroat - yellow warbler - songsparrow',
#  'Hydropsychid larvae',
#  'ants',
#  'Talitrids (amphipods)',
#  'unknown small mammal',
#  'Paranephrops zelandicus (N=6)',
#  'turtles',
#  'G. balzanii',
#  'PlnkMM1: gray whales',
#  'Paranephrops zelandicus (N=4)',
#  'blacksmith, black perch, rubber lip sea perch, sharpnose sea perch, shiner perch',
#  'Heliodidae beetle (n=2)',
#  'G. braueri (90-120mm)',
#  'herbivorous fishes',
#  'fly larvae',
#  'suspended detritus',
#  'Fools parsley',
#  'whales, crabeater seals',
#  'Benthic cephalopods',
#  'other mesopelagic fishes',
#  'Microtus - Reithrodontomys - Mus',
#  "Chironomid type 'Diamesid Brown Orange' (n=1)",
#  'Psithyrus consultus',
#  'Diatoms',
#  'landflies, adult chironomids, Achorutes',
#  'Other fishes',
#  'Hyperiid amphipods',
#  'Alphapartitivirus: Cherry chlorotic rusty spot associated partitivirus',
#  'Olla V-nigrum',
#  "Unknown rhodophyceae 'golden golfball'",
#  'gomaff',
#  'predatory invertebrates',
#  'Sum',
#  'Pseudo-Nitzschia heimii',
#  'Macrozooplankton',
#  'Copepods',
#  'producers',
#  'Dialictus oblongus',
#  'Scirtid sp. (larvae) broad type.',
#  'Unclassified microflagellates',
#  'Lobodiamesini campbelli (Pagast.)',
#  'Unknown Forb H',
#  'weevil larvae',
#  'Myotropa florea',
#  'Odontoceti',
#  'P. rugosus',
#  'D. distinctus (1.0-1.2 mm HCW)',
#  'Unidentifiable detritus',
#  'Lumbriculiid pink',
#  'Chelanops oblongus',
#  'Meso and microzooplankton',
#  'fungivorous Nematoda',
#  'Oxytheira albiceps (n=HUDSONEMA AMABILIS)',
#  'Suprabenthos',
#  'Dilepidid',
#  'misc. arthropods',
#  'Scrapers',
#  'PiscF1b: Chinook',
#  "R. l'herminieri larvae",
#  'Unreared Lepidoptera sp.20',
#  'H. repax eggs',
#  'Scianids',
#  'Dialictus zephyrus',
#  'desmids (unspec.)',
#  'Maryland yellowthroat - yellow warbler - song sparrow',
#  'littoral food items',
#  'detritus - plankton',
#  'Haemulids',
#  'Procissio',
#  'Long-billed Curlew',
#  "large-size 'Calanus type'",
#  'C. unipunctatus',
#  'Field scabious',
#  'Vascular plant material',
#  'Tanypod sp. (Chironomidae - Diptera)',
#  'Bar-tailed Godwit',
#  'Clisodon terminalis',
#  "Chironomid type 'Orthoclad blue black'",
#  'trichopterans (unspec.)',
#  'Killer Whales B',
#  'Saotis subarctor',
#  'Nannophytoplankton',
#  'Spermatophyta',
#  'Pegastia sp.',
#  'Terrestrial invert',
#  'Mosquito larvae (Uranotaenia bosseri)',
#  'rabbit carcass',
#  'CPOM',
#  'SB6: other pelagic seabirds',
#  'Thysanura, Isoptera, other Tenebrionidae',
#  'Capitellid',
#  'limpets',
#  'diatoms (mostly Cocconeis) & desmids',
#  'carnivorous Diptera',
#  'Melaniris chagresi',
#  'Croakers',
#  'predatory benthic fishes',
#  'SB4: alcids',
#  'rotifers',
#  'diatoms (unspec.)',
#  'Unknown green algal filaments',
#  'A. nuchalis',
#  'S. lunatum',
#  'Tanyderid (N=1)',
#  'plecopterans, odonates, hemipterans',
#  'autochthonous detritus',
#  'Lutjanids',
#  'Caprellid amphipods',
#  'staphylinids',
#  'nematode worms',
#  'Mites',
#  'partridge - peafowl - babbler',
#  'omnivores',
#  'Terrestrial predators living around the pitchers (spiders, mantids, dragonflies)',
#  'Cissilopha yucatanica',
#  'spiders - song birds',
#  'Phoronid',
#  'radish debris',
#  'other herbivorous gastropods',
#  'oak trees',
#  'Hyloicus separatus',
#  'Ophiuroids',
#  'owls - jaegers - fox - weasels',
#  'pocket gophers, ground squirrels',
#  'Protaphidius wissmanii',
#  'epontic microalgae',
#  'Stem tissue',
#  'Gelechia dodecella larvae',
#  'trout eggs',
#  'Dialictus coeruleus',
#  'insects - Disyonicha quinquevitata - Collembola',
#  'bearded seals',
#  'P. pini',
#  'macroalgae',
#  'Cloetus globosus',
#  'rorquals',
#  'simulids (unspec.)',
#  'Hudsonema amabilis (N=12)',
#  'Nemertines',
#  'herbivorous terrestrial insects',
#  'raptors',
#  'Z3a: E. pacifica (adult & juveniles) ',
#  'unknown red algal spp.',
#  'Roots',
#  'errant polychaeta',
#  'baleen whales',
#  'Microorganisms (bacteria, protozoa, yeast)',
#  'wading birds',
#  'gastropods, crustacea, tubificids',
#  'cacti (including seeds and fruits)',
#  'invertebrate defoliators',
#  'Tipulid sp. (Chironomidae - Diptera)',
#  'Scirtid broad spp. (N=2)',
#  'Gelechiid sp. A',
#  'chipmunks, ground squirrels',
#  'filter-feeding polychaetes',
#  'shore birds',
#  '?Nesomyza sp.',
#  'SB7: coastal seabirds (divers)',
#  'Paranephrops zelandicus (N=2)',
#  'Eukieferiella sp. II (CG)',
#  'egrets',
#  'Hydropyschid I (O)',
#  'Cephalopods',
#  'DIATOMS (Pinnularia sp.)',
#  'Ecdyonuridae',
#  'tetraphyllid fish',
#  'pore-water dissolved organic carbon',
#  'porpoise shark',
#  'Terrestrial invertebrates',
#  'detritus and benthic algae',
#  'sedimentary refractory detritus',
#  'Primary producer',
#  'penguins, petrels',
#  'herons, ibises',
#  'pike, large perch',
#  'silversides',
#  'owls, jaegers, fox, weasels',
#  'boobies',
#  'Terns',
#  'Micromoth_spC',
#  'galeld',
#  'Thanaos martialis',
#  'Erizoa olivalis',
#  'Tanypod',
#  'Rotatoria - Calanoida - Cladocera',
#  'Andrena irgeniae',
#  'top carnivores-tarpon - barracuda - bull shark - other fish - American alligator - bald eagle',
#  'doves, larks, sandgrouse',
#  'Zooplankton',
#  "Lumbriculiid type 'III' (N=10)",
#  'frogs',
#  'other hemiptera',
#  'Aelosoma sp. (CG)',
#  'other phytoplankton',
#  'decayed vegetation',
#  'SB1: sooty shearwaters',
#  'Thalandros cubensis',
#  'Villa  semifuscata',
#  'titmice',
#  'IV-VI copepodites of Calanus and Pseudocalanus',
#  'Omnivorous crabs',
#  'B. acutorostrata',
#  'Oxytheira albiceps.',
#  'Chromulinales',
#  'benthos-feeding fishes',
#  'Blackbilled Sicklebill',
#  'Cenophodes tamsi',
#  'Stomatopods',
#  'II-III copepodites',
#  'herons - ibises',
#  'Syrphus nitens',
#  'Fish-eating birds',
#  'chipmunks - ground squirrels',
#  'Protoparce quinquemaculatus',
#  'predatory bacteria',
#  'allochthonous organic matter',
#  'Flowering plants',
#  'Heteroptera sp1',
#  'Unknown green algae species',
#  'Smelt YOY',
#  'sedentary polychaeta',
#  'predaceous insects',
#  'loon, cormorant',
#  'Macrobranchium',
#  'trees and bushes',
#  'Meiobenthos',
#  'R. planifrons larvae',
#  'Wigeongrass',
#  'detritus with decomposers',
#  'Diastylis rathkii',
#  'Scotobates calcaratus larvae',
#  'CrnB2: Tanner crab',
#  'clay+bacteria',
#  'middle zone scansorial animals -- mammals in both canopy and ground zones',
#  'BnthF5: flatfish (benthic feeders)',
#  'P.curviventris',
#  'smaller copepods (e.g., Pseudocalanus)',
#  'particulate organic matter',
#  'dytiscid beetles',
#  'Hudsonema amabilis (n=1)',
#  'Costachorema xanthoptera (N=2)',
#  'bog and intertidal invertebrates',
#  'B. pumilus',
#  'annelids',
#  'wood-borers - weevils',
#  'H. carbonarius',
#  'G. sp. larvae',
#  'Unknown Forb P',
#  'Dasyphora fruticosa',
#  'Submergent vascular plants',
#  'O. ochripyga larvae',
#  'flagellates',
#  "Chironomid type 'Slant-eye'",
#  'Testate amoebae (Dufflugia sp. - Centropyxis cassis - Trigonopyxis arcula - Euglypha tuberulata - Cyclopyxis arcelloides - Arcella vulgaris - Arcella cinctus - Nebella tincta - Centropyxis platystoma)',
#  'P1: large phytoplankton',
#  'Lophiiformes',
#  'Trichopria',
#  'DIATOMS (ALL)',
#  'Dinoflaggelates',
#  'P. squamoralevis',
#  'Zealandoperla/Acroperla sp.',
#  'predaceous fish',
#  'Oligo skinny',
#  'phytoplankton',
#  'Pseudomelecta californica miranda',
#  'Wood-borers',
#  'I. calligraphus',
#  'Oxypoda longiuscula (Gravenhorst)',
#  'Halfbeaks',
#  'E. sinensis',
#  'predaceous Acari',
#  'redshank - dunlin - knot',
#  'leafhoppers',
#  'Chimarrha marginata larvae',
#  'Flathead Minnow (N=1)',
#  'simuliids (unspec.)',
#  'Macrobenthos',
#  'chaetognaths, polychaetes',
#  'C.lucasii',
#  'Aquatic insects',
#  'DIATOMS (Synedra sp.)',
#  'rodents',
#  'Adult piscivorous fish',
#  'insects (forest edge)',
#  'Emperor penguins',
#  'carnivorous vertebrate harvesters',
#  'Hummingbirds',
#  'Unidentified sp1 M_PL_045',
#  'tanaidacid',
#  'pelagic invertebrates (inc squid)',
#  'Linnaemyia soror',
#  "Chironomid type 'Tanytarsini'",
#  'larger invertebrate predators (e.g. - chaetognaths and ctenophores)',
#  'unknown Hypotrich',
#  'O. skianeuros',
#  'Picornavirus',
#  'Particulate organic carbon',
#  'Phototrophic bacteria',
#  'snakes - turtles',
#  'P. eximia eggs',
#  'EGGS (unidentified)',
#  'Psychoda sp. larvae',
#  'wood-borers, weevils',
#  'Unidentified sp9 M_PL_045',
#  'N. vespillo',
#  'tundra vegetation - berries',
#  'Empis tesselata',
#  'serpulid polychaete',
#  'E. crystallorophias',
#  'Unknown Forb N',
#  'dragonflies',
#  'Uropodid sp.',
#  'Chrysophanus helloides',
#  'reindeer dung',
#  'animal material',
#  'Unknown Forb A',
#  'Unid. Protista',
#  'dinoflagellates',
#  'fish eggs',
#  'adult helmids',
#  'pelagic crustacean',
#  'horses',
#  'Mellisuga humilis',
#  'Sipuncula',
#  'corals',
#  'lichens - mosses - phanerogams',
#  'Perissoma aenescens',
#  'marsh hawk, coyote, red-tailed hawk, weasel',
#  'Soil microflora',
#  'copepods - nematodes - bacteria',
#  'Wyeomia smithii',
#  'Pelecanus - Phalacrocorax - Sula (pelican - cormorant - gannet)',
#  'Vascular Plant Detritus',
#  'Amblymerus sp.',
#  'Aucalosira sp.',
#  'Sipunculid worms',
#  'crabs, lobsters',
#  'Kingfisher, Teal',
#  'Lumbriculiid oligochaete (N=Metriocnemus sp.)',
#  'gomcle',
#  'Acanthurus chirugus',
#  'Ceratophyllus paradoxus',
#  'Other benthos',
#  'Echinodermata',
#  'fecal material',
#  'Microtus, Reithrodontomys, Mus',
#  'Penguins',
#  'Fannidae sp.',
#  'Maoridiemesea',
#  'Z2d: fish eggs',
#  'cardinal fish',
#  'hyperparasites',
#  'Xanthocephalum sp.',
#  'allochthonous material',
#  'carnivorous fishes',
#  'PiscF8: Hexagrammidae (lingcod, greenling)',
#  'Blue Green algae',
#  'Arctostaphylus uva-ursi',
#  'jackal - hyena',
#  'Nanoflagellates and ciliates',
#  'opossums',
#  'Sphaerid (N=1)',
#  'Gobioids',
#  'Number 13',
#  'Leopard seals',
#  'BnthF3: benthivorous rockfish',
#  'trout - jack',
#  'Hyperaspis hottentota',
#  'Cottoidea',
#  'P. carlukiana',
#  'Vascular plants (13 species)',
#  'moss cells',
#  'Simosyrphus aegyptius',
#  'amorphous detritus',
#  'Other gastropods',
#  'swamp forest',
#  'Pacific herring',
#  'Rotifers',
#  'Unreared agromyzid sp.8',
#  'Psychodid (N=1)',
#  'PlnkF1b: shad',
#  'vespids',
#  'waterfowl - marsh rabbits - deer - water rat',
#  '(1 - Sum)',
#  'Chimara (N=2)',
#  'Spangled Perch',
#  'gall tissue (Atriplex canescens)',
#  'Ctenophyllus hirticrus',
#  'detritus, bacteria, fungi, ciliated protozoa',
#  'E. fusiformis',
#  'D. sicilis',
#  'pycnogonids - polychaetes - Glyptonotus - Lineus - Odonaster',
#  'vultures, crows',
#  'PlnkF1f: saury',
#  'macroalgae - eelgrass',
#  'Tetrastitchus nr. galactopus (Ratz)',
#  'large-size Appendicularia',
#  'Ptezodoratus lituratus Fabricius',
#  'Sipunculida',
#  'H. edentatus',
#  'copepods, nematodes, bacteria',
#  'frogs (unspecified)',
#  'Dipteran (not Chironomidae) larvae',
#  'blacksmith - black perch - rubber lip sea perch - sharpnose sea perch - shiner perch',
#  'Carposcalis carinata',
#  'nematode Echinuria',
#  'E. caludicans',
#  'Wind-blown organic debris',
#  'periphyton - benthic algae',
#  'urchins',
#  'Insectivorous birds (Purple sandpiper - Snow bunting (Juv.))',
#  'errant polychaetes',
#  'D1: pelagic detritus',
#  'water pipits, horned larks',
#  'Hirudenea',
#  'larger copepods (e.g. - Calanus)',
#  'T. cynipedis',
#  'anisopterid larvae',
#  'oligochaetes (unspec.)',
#  'decaying organic matter',
#  'algophagid mites',
#  'ostracods (unspec.)',
#  'harbor seals',
#  'Haplochromis codringtoni (cichlid fish)',
#  'omnivorous Nematoda',
#  ...}

# %%
for item in results:
    if 'seal' in item:
        print(item)
# Out:
# leopard seals
# seals
# whales - crabeater seals
# whales, crabeater seals
# bearded seals
# Leopard seals
# harbor seals
# Crabeater seals
# ringed seals
# harbour seal
# Weddel seals
# Weddell seals
# crabeater seals

# %%
(659+283+266+231)
# Out:
# 1439

# %%
(659) / 1993
# Out:
# 0.33065730055193177

# %%
def prepBuildTime(buildTime):
    buildTime = list(filter(lambda x: x[0] > 0,buildTime))
    buildTime = list(map(lambda x: x[1] / x[0] if x[0] > 0 else 0 ,buildTime))
    return buildTime

crush = []
exact = list(map(lambda x: ["Exact",x], prepBuildTime(getResultsForCategory(resultExact)[0])))
# genus = list(map(lambda x: ["Genus",x], prepBuildTime(getResultsForCategory(resultGenus)[0])))
# family = list(map(lambda x: ["Family",x], prepBuildTime(getResultsForCategory(resultFamily)[0])))
genus = []
family = []
crush = [*exact,*genus,*family]
dataSet = pd.DataFrame(crush,columns=['Generalisation','Time'])
ax = sns.boxplot(x="Generalisation", y="Time", data=dataSet)

# %%
sum()

# %%
def calculateSpeciesPerRecord(results):
    generated,real = results
    generated = list(map(lambda x: x[1],generated))
    generated = list(set(itertools.chain(*generated)))
    real = list(set(itertools.chain(*real)))
    if len(real) == 0: return 0 
    return len(generated) / len(real)   

def calculateSpeciesIncluded(results):
    matched = list(zip(results[0],results[1]))
    matched = list(map(calculateSpeciesPerRecord,matched))
    print(list(filter(lambda x: x < 0,matched)))
    return matched

crush = []
# calculateSpeciesIncluded(getResultsForCategory(resultExact)[3:5])
exact = list(map(lambda x: ["Exact",x], calculateSpeciesIncluded(getResultsForCategory(resultExact)[3:5])))
# genus = list(map(lambda x: ["Genus",x], prepBuildTime(getResultsForCategory(resultGenus)[0])))
# family = list(map(lambda x: ["Family",x], prepBuildTime(getResultsForCategory(resultFamily)[0])))
genus = []
family = []
crush = [*exact,*genus,*family]
dataSet = pd.DataFrame(crush,columns=['Generalisation','Time'])

fig = plt.figure()
ax = sns.violinplot(x="Generalisation", y="Time", data=dataSet,cut=0)


# This should be called after all axes have been added
fig.tight_layout()
