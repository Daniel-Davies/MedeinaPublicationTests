# %%
import os 
import matplotlib.pyplot as plt
import networkx as nx
import pickle
import itertools
import seaborn as sns
import pandas as pd
resultExact = "C:/Users/davie/Desktop/results/leaveout"
resultGenus = "C:/Users/davie/Desktop/results/leaveoutgenus"
resultFamily = "C:/Users/davie/Desktop/results/leaveoutfamily"
files = os.listdir(resultExact)
from pylab import rcParams
rcParams['figure.figsize'] = 20, 15
files[0]
# Out:
# 'BaseCSV#plantPollinatorUSA'

# %%
def getResultsForCategory(basepath):
    doneNotDone = []
    ecoTransTime = []
    buildTime = []
    results = []
    actuals = []
    files = os.listdir(basepath)
    for item in files:
        with open(basepath+"/"+item,'rb') as f:
            arr = pickle.load(f)
            result,actual,allInteractions,finalTime,translatedTime,done,notDone = arr[0]
            doneNotDone.append([done,notDone])
            namesLen = len(set(itertools.chain(*actual)))
            ecoTransTime.append([namesLen,translatedTime,item])
            results.append(result)
            actuals.append(actual)
            buildTime.append([namesLen,finalTime-translatedTime])
    return buildTime,doneNotDone,ecoTransTime,results,actuals

# %%
sum((1,3,4))
# Out:
# 8

# %%
from collections import defaultdict
ecoTransTimeExact = getResultsForCategory(resultExact)[2]
print("Done 1")
ecoTransTimeGenus = getResultsForCategory(resultGenus)[2]
print("Done 2")
ecoTransTimeFamily = getResultsForCategory(resultFamily)[2]
print("Done 3")

aggregated = defaultdict(list)
nameLenStore = {}
for nameLen, time, idx in ecoTransTimeExact:
    if time > 175: print(idx)
    aggregated[idx].append(time)
    nameLenStore[idx] = nameLen

for nameLen, time, idx in ecoTransTimeGenus:
    aggregated[idx].append(time)
    nameLenStore[idx] = nameLen

for nameLen, time, idx in ecoTransTimeFamily:
    aggregated[idx].append(time)
    nameLenStore[idx] = nameLen

ecoTransTime = list(map(lambda x: [nameLenStore[x],sum(aggregated[x])/len(aggregated[x])],list(aggregated.keys())))
dataSet = pd.DataFrame(ecoTransTime,columns=['Number of Names','Translation Time'])
ax = sns.scatterplot(x="Number of Names", y="Translation Time",data=dataSet)
labels = [w.get_text() for w in ax.get_xticklabels()]
locs=list(ax.get_xticks())
labels=['0','50','200','400','600','800','1000']
locs=[0,50,200,400,600,800,1000]
ax.set_xticklabels(labels)
ax.set_xticks(locs)
plt.xlabel("Number of Names",fontsize=25)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.ylabel("Translation Time (s)",fontsize=25)
plt.axvline(x=50,c='r')
plt.show()
# Out:
# Done 1
# Done 2
# Done 3
# FoodsWebsCanberra#WEB225
# FoodsWebsCanberra#WEB324
# FoodsWebsCanberra#WEB328

# %%
def numCorrectlyIndexed(doneAndNotDoneTuples):
    x = list(map(lambda x: x[0]/sum(x) if sum(x) > 0 else 0,doneAndNotDoneTuples))
    g = sns.distplot(x, hist=True,kde=False,bins=20)
    plt.ylabel('Frequency', fontsize = 25) # x-axis label with fontsize 15
    plt.xlabel('% of species matched', fontsize = 25) # y-axis label with fontsize 15
    for p in g.patches:
        x=p.get_bbox().get_points()[:,0]
        y=p.get_bbox().get_points()[1,1]
        g.annotate(str(int(y)), (x.mean(), y), ha='center', va='bottom',fontsize=20,c='b') # set the alignment of the text
    plt.xticks(fontsize=18)
    plt.yticks(fontsize=18)
results = getResultsForCategory(resultExact)[1]
results = list(map(lambda x: [x[0],len(x[1])],results))
numCorrectlyIndexed(results)

# %%
import itertools
results = getResultsForCategory(resultExact)[1]
results = set(itertools.chain(*map(lambda x: x[1],results)))
results
# Out:
# {'',
#  'Sum',
#  'lacewings',
#  'filter-feeding, minnow-like fishes',
#  'rabbit carcass (L. californicus)',
#  'emergent plants',
#  'copepods',
#  'T. argenteus',
#  'Phoronid',
#  'Eristalis intricarius',
#  'clams',
#  'predatory benthic fishes',
#  'tundra vegetation',
#  'young fish',
#  'cacti (including seeds and fruits)',
#  'Prinospio sp.2',
#  'Elateroidea sp2',
#  'predatory fishes',
#  'sub-surface deposit-feeding polychaetes',
#  "Chironomid type 'Diamesid blond'",
#  'sedentary polychaetes',
#  'C. semifascia',
#  'angiosperms',
#  'S. borellii',
#  'Orychmontia sp.',
#  'mosquito larva',
#  '0',
#  'Neochrysocharis arizonensis',
#  'C. nigropunctata',
#  'E. fusiformis',
#  'rhoado',
#  'berry crop',
#  'Scaly-breasted Thrasher',
#  'Coccinella 7-punctata',
#  'Unidentified green algae',
#  'Large benthopelagic fishes',
#  'P. turbida larvae',
#  'benthic diatoms',
#  'long-crested jay',
#  'upper air animals--birds and bats, insectivorous, carnivorous',
#  'Early YOY alewife',
#  'Encyrtid',
#  'Empidae spB',
#  'Woodpigeon',
#  'Platypena scabra',
#  'herb - chironomids',
#  'herbivorous fish',
#  'pyralid lepidopterans',
#  'CALANOID COPEPOD (Boeckella sp.)',
#  "Chironomid type 'Orthoclad blue black' (n=10)",
#  'Scirtid sp. (Broad type)',
#  'Mycorrhyzae',
#  'O. ochripyga larvae',
#  'Large phytoplankton',
#  'DIATOMS (Eunotia sp.)',
#  'Eukiefidrella brundini (N=6)',
#  'PlnkF1b: shad',
#  'Bony Bream',
#  "Lumbriculiid Type 'II' ",
#  'Unknown green algae spp. ',
#  'higher plants (unspec.)',
#  'prehistoric Aleut man',
#  'Diatoms - algal colonies',
#  'silversides',
#  'Cephalopodes',
#  'Stemelmis nr. Bicarinata (0.4-0.5 mm HCW)',
#  'hypoplanktonic crustacea',
#  'H. flavifacies larvae',
#  'Eliphilus latifrons',
#  'lower carnivores-various fish, copepods, blue crabs and juvenile of high carnivores',
#  'M. fuscipes',
#  'Fruit and seeds',
#  'microorganisms',
#  "Chironomid type 'Orthoclad Blue Blond' (n=4)",
#  'Euphausiid molt debris',
#  'passerines',
#  'Oligo I  (N=5)',
#  'A. inflator',
#  'Hudsonema amabilis (n=10)',
#  'mosquito larvae (unknown)',
#  'various larvae (unspecified)',
#  'Mostly cladocerans (daphnids)',
#  'T. tenuicaudus',
#  'Psithyrus consultus',
#  'alpine vegetation',
#  'Insects',
#  'mollusks (Tivela, Donax, Mesodesma) (bivalves)',
#  'Terbra',
#  'carnivorous Calanoida',
#  'decomposing sphagnum',
#  'Wild angelica',
#  'Echinodermata',
#  'DIATOMS (unidentified)',
#  'Elmid I adult (N=1)',
#  'Chrysemis',
#  'Flathead Minnow (N=1)',
#  'bumblebees - butterflies - aphids - weevils',
#  'Cryptolucilia ceasarion',
#  'Clisodon terminalis',
#  'gastropods, crustacea, tubificids',
#  'ringed seals',
#  'Zizeeria knysa Trimen',
#  'Holothurians',
#  'unidentified bird',
#  'E. antarctica (60-90mm)',
#  'bryophyte',
#  'benthos (micro meio and macro)',
#  'Aelosoma spp. (N=Metriocneums sp.)',
#  'BnthF1: skates & rays',
#  'fish - birds - mammals',
#  'wood-borers, weevils',
#  "Chironomid type 'Slant-eye'",
#  'Eukieflidrella brundini',
#  'Haemulids',
#  'unknown ciliate',
#  'UNIDENTIFIED FISH (WHOLE)',
#  'Terrestrial invertebrates',
#  'belvedere summer cypress (forb/shrub)',
#  'Baetid nymphs',
#  'Benthic feeding fish',
#  'phytoplankton - periphyton',
#  'Myiatropa sp.',
#  'A. nuchalis',
#  'spiders (forest edge)',
#  'ants',
#  'CYCLOPOID COPEPODS (FRAGMENTS)',
#  'Tristhema mauritiana',
#  'Anisopterid larvae',
#  'intertidal and marine invertebrates',
#  'P. corruscans',
#  'Pisces -- Rhinichthys - Semotilus',
#  'three-cleft greenthread (forb/shrub)',
#  'Muscid_sp.',
#  'Peirretia',
#  'Benthic invertebrates (F/D/S)',
#  'Whales',
#  'Oligo smooth (N=10)',
#  'Meadow vetchling',
#  'UNIDENTIFIED INVERTEBRATE (FRAGMENTS)',
#  'CPOM',
#  'Chrysomonads',
#  'Micromoth_spC',
#  "large-size 'Acartia type'",
#  'Epeolus helianthi',
#  'copepods - Orchomonopsis',
#  'large detritus particles',
#  'Cnidarians (Hydromedusae - Scyphomedusae)',
#  'pelagic invertebrates (inc squid)',
#  'European Carp',
#  'Unreared Lepidoptera sp.27',
#  'bombus americanorum',
#  'Dermasothes gracile',
#  'Ecdyonuridae',
#  'Unreared agromyzid sp.13',
#  'predatory planktonic invertebrates',
#  'predatory zooplankton',
#  'T. paraguayensis',
#  'submerged macrophytes (Blyxa, Cryptocoryne, Nitella)',
#  'Polypedellum (N=4)',
#  'Anisostena championi (Baly)',
#  'Polypedellum  (N=6)',
#  'Mellisuga humilis',
#  'halictid',
#  'Oxypoda longiuscula (Gravenhorst)',
#  'herbivorous insects',
#  'Unknown blue green algal spp.',
#  'Scotobates calcaratus larvae',
#  'Scirtid narrow (N=1)',
#  'Hudsonimya (N=1)',
#  'decayed vegetation',
#  'Pisobia',
#  'oligochaetes (unspec.)',
#  'Carposcalis carinata',
#  'K. serrulata',
#  'Andrena irgeniae',
#  'meibenthos',
#  'silphids',
#  'other pelagics',
#  'Fish larvae',
#  'bumblebees',
#  'young Pinus sp.',
#  'Unknown rotifers',
#  'Unknown Forb P',
#  'Large terrestrial inverts',
#  'Penguins',
#  'copepodites',
#  'Mugilids',
#  'mollusks - sponges',
#  'Discard',
#  'H. morosa',
#  'Mollies',
#  'pocket gophers - ground squirrels',
#  'Trich and Ephem - c',
#  'Microcrustaceans',
#  'protozoa (fresh water bottom and littoral)',
#  'unknown flagellate',
#  'Andrena cressoni',
#  'defoliating invertebrates, small rodents',
#  'mesozooplankton',
#  'Parasarcophaga hirtipes',
#  'other hemiptera',
#  'D. sicilis',
#  'Predatory fishes',
#  'O. gallaram',
#  'Flounder and needlefish',
#  'Pelecypoda',
#  'Parasitoids (Synodites lineiger - Ichneutes hyperboreus)',
#  'Uropodid sp.',
#  'Unreared Lepidoptera sp.1',
#  '17',
#  'decomposing soil fauna',
#  'Plactynemis',
#  'terrestrial insects (unspec.)',
#  'other mites',
#  'Larger ciliates (omnivore)',
#  'Ababesmya karelia',
#  'Oligo II',
#  'dissolved organic matter',
#  'M. fasciiventris',
#  'Stenophylax stellatus',
#  'crickets',
#  'Salps',
#  'intertidal invertebrates',
#  'Black-winged Stilt',
#  'unknown forbs',
#  'Osmia rohweri',
#  'ALGA FRAGMENTS (unidentified)',
#  'juvenile euphausiids',
#  'Parasitoid (Atractodes pusillus)',
#  'Olla v-nigrum',
#  'Neoblattela fraterna',
#  'Capitellid 1',
#  'Anthrax halycon',
#  'sharp-shinned hawk',
#  'Piscivorous fish',
#  'Caprellid amphipods',
#  'cardinal fish',
#  'Zaommomyia sp.C',
#  "Cooper's and sharpshinned hawks",
#  'water pipits, horned larks',
#  'owls, jaegers, fox, weasels',
#  'perch fry and adults',
#  'dipterous larvae',
#  'Nematode ',
#  'secondary carnivores',
#  'Copepods',
#  'man',
#  'Large single-cell algae or colonies',
#  "Chironomid type 'Orthoclad blue black'",
#  'A. quercicola',
#  'PiscMM1: small pinnipeds',
#  'Hydrophilid unknown sp.',
#  'Zooplanckton',
#  'sedimentary labile detritus',
#  'Myliobatoidei',
#  'pulverized masses',
#  'nematode Echinuria',
#  'H. repax larvae',
#  'Unid. Macrophytes',
#  'Chrysophanus sirius',
#  'Antherix - Eucalia',
#  'browsers and grazers (gastropods - crustacea - etc.)',
#  'Demersal piscivores',
#  'land vegetation',
#  'Unidentified fly sp1',
#  'Cephalopods (Loligo opalescens)',
#  'Unreared hispine sp.7',
#  'rodents',
#  'large sharks',
#  'Cephalopod',
#  'stream and airborne insects',
#  'S. lunatum',
#  'moss cells',
#  'Oligo. Lumbr. Pink (CG)',
#  'Imports',
#  'Recently drowned insects',
#  'fish eggs',
#  'Acnanthidium saxonica',
#  'Synechoccus',
#  'Scirtid broad spp. (N=2)',
#  'Lumbr Pinkk (N=10)',
#  'Scirtid spp. (larva) (n=HYDORA NITIDA)',
#  'Eukiefiriella (N=3)',
#  'baleen whales',
#  'toad carrion',
#  'blue crabs',
#  'shrews (3 species)',
#  'Oligo II (N=5)',
#  'Hirudenea',
#  'porcupines',
#  'ephemopteran (unspecified)',
#  'fish larvae',
#  'Mosquito larvae (Uranotaenia bosseri)',
#  'adult Cyclops',
#  'rubber lip sea perch',
#  'P. pini',
#  'Saprinus pennsylvanicus',
#  'Patellogastropoda',
#  'Killifishes',
#  'Perissoma aenescens',
#  'Desmidiales',
#  'mixed-food consumers',
#  'HNF',
#  'Macrocheles muscadomesticae',
#  'Others',
#  'Weddel seals',
#  'defoliating invertebrates - small rodents',
#  'Dead cellular plant material',
#  'redshank, dunlin, knot',
#  'crabs - shrimps - gold-spotted killifish - crested goby',
#  'canopy -- leaves - fruits - flowers',
#  'BnthF7: grenadier',
#  'large-size Appendicularia',
#  'Maoridiemesea',
#  'gomnew',
#  'filter feeders (molluscs, sponges, plumatella)',
#  'boobies',
#  "Lumbriculiid type 'Smooth'",
#  'Alphanodavirus: Black beetle virus',
#  'SB6: other pelagic seabirds',
#  'rorquals',
#  'gall tissue (Atriplex polycarpa)',
#  'swallows',
#  'Tendipedidae (unspecified)',
#  'Lyniphia triangularis Clerck',
#  'Clupeids',
#  'T. auratus',
#  'benthic-diatoms',
#  'Primary producers',
#  'plankton, suspended detritus',
#  'Leuceria salina',
#  'Osmia coloradella',
#  'A. fecundator',
#  'grasshopper mice',
#  'Aufwuchs on Vallisneria',
#  'Hudsonema aliena (N=2)',
#  'Nebella',
#  'Trichopria',
#  'harbor seals',
#  'UNIDENTIFIED INSECT (FRAGMENT)',
#  'recently drowned insects',
#  'Oligo I ',
#  'predaceous Collembola',
#  'anemones',
#  'Hirudinea (Erpobdella, Helobdella)',
#  'lambs-quarter (forb/shrub)',
#  'unknown bacterium',
#  'Other benthos',
#  'Goldfish',
#  'Live insects visiting the pitcher',
#  'fry',
#  'emergent vascular plants',
#  'Crayfish (N=4)',
#  'cheatgrass brome (grass)',
#  'Gatherers',
#  'rays',
#  'copepods - nematodes - bacteria',
#  'allochthonous organic matter',
#  'Scirtid sp. larvae (Broad type)',
#  'meroplankton - fish larvae',
#  'top carnivores-tarpon, barracuda, bull shark, other fish, American alligator, bald eagle,',
#  'Brachyptera fasciata (0.4-0.6 mm HCW)',
#  'gastropods - pelecypods',
#  'Squids',
#  'Z1ai: copepods (large, >= 0.025mg C)',
#  'Elmid larvae',
#  'calanoids - small tomopterids - small coelenterates',
#  'Amphithoe valida',
#  'phytoplankton and benthic algae',
#  'Hudsonema amabilis (N=1)',
#  'Oysters',
#  'Zooplanktivorous fish',
#  'acorns',
#  'Arctinula groenlandica',
#  'barnacles',
#  'submerged macrophytes (Blyxa - Cryptocoryne - Nitella)',
#  'Nephentes pervillei',
#  'Nymphalis polychlorus',
#  'unknown snake',
#  "Chironomid type 'Diamesid Blond' (n=10)",
#  'Prosopis elliptica',
#  'bottom detritus',
#  'fragmented leaf, stem tissue, moss',
#  'flowers',
#  'Adoxia',
#  'Oligo Lumbri pink (N=10)',
#  'fungivorous Nematoda',
#  'blacksmith, black perch, rubber lip sea perch, sharpnose sea perch, shiner perch',
#  'D. tenebrans',
#  'seeds of other plants',
#  'marsh plants',
#  'Melanerpes carolinensis',
#  'trees and bushes',
#  'misc. arthropods',
#  'protozoa, rotifers',
#  'Plankton',
#  'Scianids',
#  'Actinomycetes',
#  'beetles - spiders',
#  "Chironomid type 'Polyped' (n=TANYTARSINI)",
#  'Other fish',
#  'P. ternetzi',
#  'A. quadrilineatus',
#  'other green algae (unspec.)',
#  'benthos-feeding fishes',
#  'podurids (unspec.)',
#  'Costachorema xanthoptera (N=3)',
#  'Capitellid 2',
#  'Unknown Forb F',
#  'Suspension-feeding molluscs',
#  'Bivalves',
#  'Anth spF',
#  'Paranyctiophylax sp. (N=5)',
#  'invertebrates',
#  'benthic filter-feeders',
#  'mosquito larvae',
#  'ice invertebrates',
#  'Bryozoans',
#  'Rotifers and veligers',
#  'Epiphyte-grazing amphipods',
#  'Micromoth_spB',
#  'omnivores',
#  'E. antarctica (90-120mm)',
#  'P. jezoensis',
#  'Reinhardtius hipoglossoides',
#  'pycnogonids - polychaetes - Glyptonotus - Lineus - Odonaster',
#  'Syrphus nitens',
#  'Strictopterinae sp1',
#  'Cyanobacteria (mainly Nostoc commune)',
#  'plankton - detritus',
#  'P. rugosus',
#  'panphytophagous Collembola',
#  'bombus dorsalis',
#  'Peracarida',
#  'flagellates - diatoms',
#  'Northea hornei',
#  'L. acaulis',
#  'fox Vulpes vulpes',
#  'insects in soil stratum - wire worms - cutworms - white grubs - etc.',
#  'Linnaemyia soror',
#  'Potamo - Bithyn - Lymn',
#  'flies - Dermestes - Calliphora - Phaleria (carrion beetles and flies)',
#  'Aelosoma sp. (CG)',
#  'cutworms - grasshoppers - clickbeetles',
#  'Croakers',
#  'beetles',
#  'Hylema platura',
#  'mycetophilid larvae (undet.)',
#  'harbour seal',
#  'P. maculatus',
#  'Detritivorous fish',
#  'CALANOID COPEPOD (unidentified)',
#  'chipmunks, ground squirrels',
#  'benthic bacteria',
#  'Tanypinae',
#  'Carnivorous zooplankton',
#  'Carnivorous fishes',
#  'DIATOMS (Pinnularia sp.)',
#  'bog and intertidal invertebrates',
#  'II-III copepodites',
#  'soil insects, mites',
#  'Killer Whales A',
#  'middle zone scansorial animals -- mammals in both canopy and ground zones',
#  'Kingfisher - Teal',
#  'meadow insects',
#  'O. euedoreschus',
#  'epipellic flora',
#  'six-weeks fescue (grass)',
#  'oak trees',
#  'I. calligraphus',
#  'titmice',
#  'shrimps',
#  'predatory bacteria',
#  'Paranephrops zelandicus',
#  'Diastylis rathkii',
#  'total litter',
#  'Belonoids',
#  'Pearl spots',
#  'Hudsonimya sp.(N=1)',
#  'Vascular plant material',
#  'large benthic carnivores',
#  'larger copepods (e.g. - Calanus)',
#  'A. curvator',
#  'macroarthropod f',
#  'Unknown organic',
#  'dragonflies',
#  'Unreared Lepidoptera sp.32',
#  'Dolphins',
#  'Epipellic Flora',
#  'periphyton - benthic algae',
#  'plants',
#  'Terrestrial bugs',
#  'Hudsonema aliena (N=1)',
#  'phytoplankton cells below 10 micrometer',
#  'antelopes, gazelle, backbuck, nilgai',
#  'cutworms, grasshoppers, clickbeetles',
#  'littoral food items',
#  'microinorganic particles',
#  'Simosyrphus aegyptius',
#  'Crabeater seals',
#  'toothed whales',
#  'Cecid_spA',
#  'Tanaisus sp.',
#  'D3: benthic detritus',
#  'Z2c: other macro-zooplankton ',
#  'doves - larks - sandgrouse',
#  'P. pullus',
#  'nematode n',
#  'coots',
#  'Oligo skinny',
#  'ground--roots, fallen fruit, leaves and trunks',
#  'Unknown green algae spp.',
#  'geese',
#  'IV-VI copepodites of Calanus and Pseudocalanus',
#  'large phytoplankton',
#  'Unreared hispine sp.9',
#  'ducks',
#  'vermetids',
#  'Unidentified sp6 M_PL_045',
#  'UNIDENTIFIED ANIMAL FRAGMENTS',
#  'P. turbida pupae',
#  'P. eximia eggs',
#  'invertebrate defoliators',
#  'staphylinids',
#  'partridge, peafowl, babbler',
#  'unidentified seeds (forb/shrub)',
#  'insects, Disyonicha quinquevitata, Collembola',
#  'Other detritus feeders',
#  'antelopes - gazelle - backbuck - nilgai',
#  'benthonic invertebrates',
#  'oligochaetes',
#  'Unidentified voucher No.28',
#  'SB7: coastal seabirds (divers)',
#  'G. sp. larvae',
#  'spiders',
#  'Leopard seals',
#  'waterfowl, marsh rabbits, deer, water rat',
#  'terns, shorebirds',
#  'invertebrate predators',
#  'Predatory shrimps',
#  'gall tissue (Atriplex canescens)',
#  'soil organic matter',
#  'Chimara (N=2)',
#  'dolicopodid larvae',
#  'Scirtid sp. (larva) (n=3) ',
#  'jaegers',
#  'cormorant - heron - merganser',
#  'pelecypod 2',
#  'Herbivorous Crustaceans',
#  'Phoronida',
#  'nematode p',
#  'Brachyptera fasciata',
#  'Galloanserae',
#  'large sized Euphausiacea, Mysidacea, Hyperiidea, Ostracoda',
#  'Z2d: fish eggs',
#  'galerucella decora',
#  'Podonomid sp.(n=4)',
#  'Sediment',
#  'Terrestrial plant material',
#  'Kaibab squirrel',
#  'Phytodecta olivacea (Forster)',
#  'U. brunhesi',
#  'vultures - crows',
#  'M. tibialis',
#  'phloem (Quercus spp.)',
#  'lower carnivores-various fish - copepods - blue crabs and juvenile of high carnivores',
#  'annuals (Monsonia - Stipagrostis - Eragrostis)',
#  'redalg',
#  'suspended or deposited organic matter',
#  'P. tenisoni',
#  'fine particulate organic matter',
#  'Z2a: pelagic amphipods',
#  'SB8: storm-petrels',
#  'PiscF4: piscivorous rockfish',
#  'Dileptis',
#  'snakes, varanids',
#  'epiphytic and benthic algae',
#  'capitellid 1',
#  'emergent herbivorous insects',
#  'Crystal Krill',
#  'snakes - varanids',
#  'Pied Billed Grebe',
#  'Adult planktivorous fish',
#  'Sciarid_spA',
#  'littoral browsers',
#  'spiders (mature forest)',
#  'Unknown Forb D',
#  'Benthic infauna',
#  'planktonic bacteria',
#  'animal carcasses',
#  'Scirtid skinny (N=1)',
#  'roots',
#  'Loggerhead turtles',
#  'epibenthic crustacea',
#  'Lutjanids',
#  'bombus edwardsi',
#  'Anth spD',
#  'grass Schismus barbatus',
#  'IV-VI copepodites of Paracalanus',
#  'shore birds',
#  'FISH SCALES',
#  'polychaetes',
#  'C. puncticollis adults',
#  'Tanyderid sp. ',
#  'limpets',
#  'Other Chironomidae',
#  'Adult Diptera',
#  'Euspilotus aenicollis',
#  'Krill larvae',
#  'Tardigrade unknown',
#  'Other insectivores',
#  'Predatory mites (Gamasidae + Prostigmata - 4 spp. Inc. Zircon sp.)',
#  'Snappers',
#  'Halictus manitonellus',
#  'Large rotifers (carnivore)',
#  'Other phytoplankton',
#  'lichens, mosses, phanerogams',
#  'Other copepods',
#  'PROTOZOA: Cyphoderia sp.',
#  'Spiders',
#  'Capitellid',
#  'Acnanthidium saxonica ',
#  'P. lecontei',
#  'waterfowl - lemmings - squirrels',
#  'Z1c: invertebrate eggs',
#  'D. nepenthicola',
#  'gall tissue',
#  'prawns and shrimps',
#  'Muscomorpha',
#  'FISH (ALL except EGGS)',
#  'mid-water feeding fishes',
#  'Gudgeon',
#  'turtles',
#  'Simulidae, Cricotopus, triannulatus, Orthocladius',
#  'Brittle stars',
#  'Tetrastitchus nr. galactopus (Ratz)',
#  'T. multicrinis',
#  'Amphipod unknown',
#  'mammals',
#  'P. foveolata larvae',
#  'SspB3: misc. epifauna (suspension feeders)',
#  'Basilarchia weidemeyeri',
#  'Adult piscivorous fish',
#  'Dasyphora fruticosa',
#  'Protozoa',
#  'Microspora',
#  'Empidae spC',
#  'deposit feeders',
#  'Z3a: E. pacifica (adult & juveniles) ',
#  'Eukiefidrella',
#  'benthonic vertebrates',
#  'Empidae spA',
#  'Terrestrial plants',
#  'Unreared agromyzid sp.19',
#  'middle zone flying animals--birds and insectivorous bats',
#  'interstitial fauna (Foraminifera)',
#  'Hudsonema amabilis (n=1)',
#  'Empis tesselata',
#  'Macoma - Cardium',
#  'D. distinctus (0.4-0.6 mm HCW)',
#  'Microprotozoa',
#  'juvenile Thermocyclops',
#  'Paranephrops zelandicus ',
#  'mycetyphagid (undet.)',
#  'Sipuncula',
#  'litter - detritus - humus',
#  'kittiwakes',
#  'Grapta hylas',
#  'dinoflagellates',
#  'sponges',
#  'Sharks',
#  'Stemelmis nr. Bicarinata (0.1-0.2 mm HCW)',
#  'marsh hawk, coyote, red-tailed hawk, weasel',
#  'C.lucasii',
#  'browsers and grazers (gastropods, crustacea, etc.)',
#  'Limicolae, Anseres, Microtus (2 sp.), Arvicola',
#  'Costachorema xanthoptera',
#  'Chimarrha marginata larvae',
#  'Geosargus cuprarius',
#  'Anoncus gallicola',
#  'spiders, song birds',
#  'CYCLOPOID COPEPODS (Mesocyclops sp.)',
#  'Unknown grn algae',
#  'Microinorganic particles',
#  'harrier hawks',
#  'Hydropyschid I (O)',
#  'snakes, gharial, turtles',
#  'Staphylinids (rove beetles)',
#  'insects in herb and surface stratum - Diptera - Hemiptera - grasshoppers - etc.',
#  'gelatinous zooplankton',
#  'Macquartia brevicornis (Panzer)',
#  'Nematods',
#  'Parasitoids (Aclastus borealis - Gelis glacialis)',
#  'algal mats - crusts',
#  'Unreared Lepidoptera sp.34',
#  'fishes (type 3)',
#  'zoobenthos',
#  'Moss cells',
#  'butterflies - moths',
#  'benthos(micro, meio and macro)',
#  'Yabby',
#  'rotifers',
#  'Capitellid 3',
#  'microprotozoa',
#  'Syrphid',
#  'bobcats',
#  'diatoms',
#  'Number 40',
#  'Wyeomia smithii',
#  'hawks and owls (7 species)',
#  'Mammals',
#  'Number 13',
#  'carnivorous invertebrates',
#  'Saotis boreator',
#  'Rays',
#  'other fish',
#  'Thalandros cubensis',
#  'P. turbida adults',
#  'Stictoclcaius',
#  'Olla V-nigrum',
#  'Benthic bacteria',
#  'waterfowl - marsh rabbits - deer - water rat',
#  'suspended detritus',
#  'fish carnivores',
#  'Unreared Lepidoptera sp.11',
#  'shore crabs',
#  'Smelt YOY',
#  '(1 - Sum)',
#  'N. numismalis',
#  'Betanodavirus: Striped jack nervous necrosis virus',
#  'bivalves - nematodes - cumaceans - polychaetes - small crustacea - fish',
#  'tartigrades',
#  'Pinixia floridana',
#  "Lumbriculiid type 'skinny' (N=10)",
#  'Hudsonema amabilis (n=3)',
#  'cecidomyid larvae (undet.)',
#  'pike, adult yellow perch (Perca)',
#  'Filterers',
#  'Zaommomyia sp.D',
#  'Crustacean Parts',
#  'bivalves, nematodes, cumaceans, polychaetes, small crustacea, fish',
#  'terrestrial beetles',
#  'wood rats',
#  'Barnacles',
#  'Hydropyschid I (N=10)',
#  'Eukaryote- yeast',
#  'Eukiefidrella brundini (N=2)',
#  'Microtus - Reithrodontomys - Mus',
#  'Maryland yellowthroat, yellow warbler, songsparrow',
#  'Single-cell algae',
#  'Bottom-feeding fishes',
#  'Large wedge shell',
#  'Vascular Plant Detritus',
#  'Dipteran (not Chironomidae) larvae',
#  'Iridomyrmex pruinosum',
#  'zooplankton, bacteria',
#  "Chironomid type 'Orthoclad blue blond' (n=ORTHOCLAD BLUE BLACK)",
#  "Lumbriculiid type 'II' (N=10)",
#  'Goniadid 1',
#  'Scirtid sp. larvae (Skinny type)',
#  'Unknown Forb H',
#  'Podonomid type hairy (N=1)',
#  'isopods, Gammarus, Caprella',
#  'Polypedellum green type (N=8)',
#  'mollusks (Tivela - Donax - Mesodesma) (bivalves)',
#  'flowering plants',
#  'A. orientalis larvae',
#  'S. utilis larvae',
#  'Z2f: large jellyfish ',
#  'Hesionid 1',
#  'Scirtid sp. (larvae) broad type.',
#  'trichopterans (unspec.)',
#  'Shrimps',
#  'B. pumilus',
#  'C. macellaria larvae',
#  'Trumpet Manucode',
#  'protozoa (fresh water plankton)',
#  'insects (mature forest)',
#  'Unreared hispine sp.6',
#  'Meiobenthos',
#  'Eukieferiella sp. II (N=10)',
#  'reindeer dung',
#  'detritus, organic matter',
#  'Loricate rotifers',
#  'Lissogaster subcompleta',
#  'swallows - bats - Chordeiles (nighthawk)',
#  'Eurois occulata',
#  'Aganais borbonica Boisduval',
#  'pollen (undet.)',
#  'Eukieffidrella pseudomontana (N=1)',
#  'Stemelmis nr. Bicarinata (0.2-0.3 mm HCW)',
#  'JuvF1: juvenile rockfish',
#  'Unknown red algae spp.',
#  'Hyperaspis hottentota',
#  'Lichens (Cladonia spp + Cetraria delisei)',
#  'nearshore phytoplankton',
#  'meroplankton, appendicularians, doliolids',
#  'L. geniculata',
#  'Sipunculida',
#  'Gelatinous zooplankton',
#  'pore-water dissolved organic carbon',
#  "McCown's longspur",
#  "Lumbriculiid Type 'Smooth' (N=10)",
#  'U. bosseri',
#  'Nemertine 3',
#  'herons - ibises',
#  'ophiuroids',
#  'Chromulinales',
#  'Syntomaspis cyanea',
#  'piscivorous fish',
#  'Sepsid B larvae',
#  'Polypedellum',
#  'Trichiotinus bidens larvae',
#  'terrestrial inverteb. (hymenopteran)',
#  'Unreared Lepidoptera sp.22',
#  'Horse mackerels',
#  'diatoms in surface film',
#  'Demersal fish',
#  'epontic microalgae',
#  'Unidentified sp2 M_PL_052',
#  'Zwickia',
#  'phytoplankton (large particles)',
#  'baetids (unspec.)',
#  'Herrings',
#  'parasitic hymenopterous larvae',
#  'pochard - swan - coot',
#  'crickets, grasshoppers, caterpillars',
#  'Selachimorpha',
#  'zooplankton - bacteria',
#  'Dialictus microlepiodes',
#  'Oligo I (N=10)',
#  'Lumbriculiid oligochaete (N=Metriocnemus sp.)',
#  'Indigenous catfishes',
#  'iron bacteria',
#  'Terns',
#  'syrphid larvae',
#  'B. acutorostrata',
#  'Myotropa florea',
#  'long-eared owl',
#  'Unreared Lepidoptera sp.6',
#  'hoppers, ants, termites, beetles',
#  'filter-feeding polychaetes',
#  'Melitaea whitneyi',
#  'mesopelagic',
#  'Entomostraca, Rotifera, Tardigrada, Oligochaeta, Nematoda (fresh water bottom and littoral)',
#  "large-size 'Oithona-Oncaea type'",
#  'other herbivorous plankton',
#  'dipterans',
#  'Unidentified cockroach sp1',
#  'spiders - passerines - dragonflies',
#  'unknown small mammal',
#  'plankton',
#  'acorn barnacles',
#  'terrestrial flies',
#  'algal mats, crusts',
#  'Zooplankton',
#  'T. tenvicaudus',
#  'Potamya',
#  'Hudsonema amabilis',
#  'littorines',
#  'Sericothrips variabilis',
#  'BENTHIC DIATOMS',
#  'fish herbivores',
#  'Roots',
#  'meadow lark, chipping sparrow, clay-colored sparrow, vesper sparrow, horned lark, upland plover',
#  'planktivorous fishes',
#  'smaller toothed whales',
#  'chaetognaths, polychaetes',
#  'Long-billed Curlew',
#  'Euchanis',
#  'phytoplankton cells above 30 micrometer',
#  'bottom organic matter, benthic macroalgae',
#  'Myiatropa florea',
#  'Spiny Lobsters',
#  'Carnivorous Crustaceans',
#  'Shredders',
#  'Satyrium w-album',
#  'algophagid mites',
#  'Lobsters',
#  'Chrysobothris sp. larvae',
#  'Amphi-trematode sp.',
#  'tansy leaf aster (forb/shrub)',
#  'Paleomonetes',
#  'detritus, plankton',
#  'SPOM',
#  'PlnkF2a: coho yearling',
#  'Dinoflaggelates',
#  'dead organic material',
#  'mites - centipedes',
#  'pelagic crustacean',
#  'Unid. Bacteria',
#  'Large Zoo',
#  'Aelosoma sp. (N=ANTOCHA SAXICOLA)',
#  'galgol',
#  'porpoise shark',
#  'pycnogonids, polychaetes, Glyptonotus, Lineus, Odonaster',
#  'Decapods',
#  'Oligo Lumbr. Blue (N=2)',
#  'Juvenile spider',
#  'encrusting and mat-forming algae',
#  'Blackbilled Sicklebill',
#  'Sphex sabulosa',
#  'Gerreids',
#  'dolicopodid larvae (undet.)',
#  'Maryland yellowthroat - yellow warbler - songsparrow',
#  'BBgull',
#  'other copepods',
#  'Ostracods',
#  'P. vulgaris',
#  'Oribatei sp.',
#  'Costachorema xanthoptera (N=2)',
#  'P. curviventris',
#  'misc. fur, feather, fin',
#  'Ecdyurus venosus',
#  'bottom organic matter',
#  'Stenanthidium espinosai',
#  'Coilodes castanea',
#  'B. herodes',
#  'canopy animals--birds, fruit bats and other mammals',
#  'Temnostoma aequale',
#  'gerrids (unspec.)',
#  'Chalcidoma disjunctum',
#  'terrestrial detritus',
#  'forest roaches',
#  'pochard, swan, coot',
#  'Eukieferiella sp. II (CG)',
#  'Pelecophora intemipta All',
#  'Sponges',
#  'Eukieflidriella brundini',
#  'Chamaenerium angustifolium',
#  'emerging aquatic invertebrates',
#  'detritus - organic matter',
#  'H. carbonarius',
#  'honeybees',
#  'Arenicola',
#  'Pyramidellid 1',
#  'tachinid larvae',
#  'Echinoids',
#  'various larvae (unsp.)',
#  'Galaxias brevipennis (N=1)',
#  'mangrove leaf detritus',
#  'Fellostomatid',
#  'benthos-eating fish',
#  'A. longimana',
#  'lumbricid (undet.)',
#  'Lumbriculiid oligochaete (CG)',
#  'Ectoparasites (Phthiraptera)',
#  'Pseudomelecta californica miranda',
#  'Hyperiidea',
#  'detritus with decomposers',
#  'Aufwuchs',
#  'young chironomids',
#  'unknown vegetation',
#  'Tanyderid (N=1)',
#  'Alphapartitivirus: Cherry chlorotic rusty spot associated partitivirus',
#  'nauplii of Copepoda',
#  'Large rotifers (omnivore)',
#  'Mojarras',
#  'Oligochaete Type I',
#  'primary carnivores',
#  'Pelecypod 1',
#  'O. skianeuros',
#  'Hirud - Tricladida - Hydrachn',
#  'Argyranthemum teneriffae',
#  'T. sinuatus',
#  'ground -- roots - fallen fruit - leaves and trunks',
#  'anemones, tunicates',
#  'canopy--leaves, fruits, flowers',
#  'Gobies and blennies',
#  'insects (forest edge)',
#  'jackal - hyena',
#  'Tipulid',
#  "Bonaparte's Gull",
#  'diatoms (unspec.)',
#  'Phrea',
#  'Juvenile fish',
#  'older organic debris',
#  'tundra vegetation - berries',
#  'detritus - plankton',
#  'large-sized phytoplankton',
#  'Acarida',
#  'CYCLOPOID COPEPOD (Eucyclops sp.)',
#  'Unknown green algal filaments',
#  'DINOFLAGELLATE (unidentified)',
#  'turtle grass',
#  'galeld',
#  'A. fimetarius',
#  'PiscMM2: large pinnipeds',
#  'Tachinid sp.',
#  'predatory cephalopods',
#  'Ceratopogonid sp. ',
#  'weasels',
#  'PiscF9: flatfish (water-column feeders)',
#  'Unknown blue green algae',
#  'Heterotrophic bacteria',
#  'predatory mite',
#  'Terrestrial invert',
#  'wind-blown organic debris - pollen',
#  'Sprivivirus: Pike fry rhabdovirus',
#  'Canosoma crassus',
#  ...}

# %%
for item in results:
    if 'seal' in item:
        print(item)
# Out:
# ringed seals
# Weddel seals
# harbor seals
# harbour seal
# Crabeater seals
# Leopard seals
# seals
# Weddell seals
# whales, crabeater seals
# leopard seals
# crabeater seals
# bearded seals
# whales - crabeater seals

# %%
(659+283+266+231)
# Out:
# 1439

# %%
(659) / 1993
# Out:
# 0.33065730055193177

# %%
def prepBuildTime(buildTime):
#     buildTime = list(map(lambda x: x[1],buildTime))
    buildTime = list(map(lambda x: x[1] / x[0] if x[0] > 0 else 0 ,buildTime))
    return buildTime

crush = []
exact = list(map(lambda x: ["Exact",x], prepBuildTime(getResultsForCategory(resultExact)[0])))
genus = list(map(lambda x: ["Genus",x], prepBuildTime(getResultsForCategory(resultGenus)[0])))
family = list(map(lambda x: ["Family",x], prepBuildTime(getResultsForCategory(resultFamily)[0])))
# print(exact[0:10])
# genus = []
# family = []
print(len(list(filter(lambda x: x[1] >= 12,family))))
family = list(filter(lambda x: x[1] < 12, family))
crush = [*exact,*genus,*family]
dataSet = pd.DataFrame(crush,columns=['Generalisation','Time'])
ax = sns.boxplot(x="Generalisation", y="Time", data=dataSet,palette=sns.color_palette("RdBu", n_colors=7)[::-1])
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.ylabel('Time', fontsize = 25) # x-axis label with fontsize 15
plt.xlabel('Generalisation', fontsize = 25) # y-axis label with fontsize 15
# Out:
# 4
# Text(0.5, 0, 'Generalisation')

# %%
def calculateSpeciesPerRecord(results):
    generated,real = results
    generated = list(map(lambda x: x[1],generated))
    generated = list(set(itertools.chain(*generated)))
    real = list(set(itertools.chain(*real)))
    if len(real) == 0: return 0 
    return len(generated) / len(real)   

def calculateSpeciesIncluded(results):
    matched = list(zip(results[0],results[1]))
    matched = list(map(calculateSpeciesPerRecord,matched))
    print(list(filter(lambda x: x < 0,matched)))
    return matched

crush = []
# calculateSpeciesIncluded(getResultsForCategory(resultExact)[3:5])
exact = list(map(lambda x: ["Exact",x], calculateSpeciesIncluded(getResultsForCategory(resultExact)[3:5])))
genus = list(map(lambda x: ["Genus",x], calculateSpeciesIncluded(getResultsForCategory(resultGenus)[3:5])))
family = list(map(lambda x: ["Family",x], calculateSpeciesIncluded(getResultsForCategory(resultFamily)[3:5])))
# genus = []
# family = []
crush = [*exact,*genus,*family]
dataSet = pd.DataFrame(crush,columns=['Generalisation','Time'])

fig = plt.figure()
ax = sns.violinplot(x="Generalisation", y="Time", data=dataSet,cut=0,palette=sns.color_palette("RdBu", n_colors=7)[::-1])


# This should be called after all axes have been added
fig.tight_layout()
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.ylabel('Time', fontsize = 25) # x-axis label with fontsize 15
plt.xlabel('Generalisation', fontsize = 25) # y-axis label with fontsize 15
# Out:
# []
# []
# []
# Text(0.5, 111.5, 'Generalisation')
